# %%
from pandas.plotting import lag_plot
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams.update({'ytick.left' : False, 'axes.titlepad':10})

# Import
ss = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/sunspotarea.csv')
a10 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv')

# %%
ss.head()
# Out:
#          date       value
# 0  1875-01-01  213.133333
# 1  1876-01-01  109.283333
# 2  1877-01-01   92.858333
# 3  1878-01-01   22.216667
# 4  1879-01-01   36.333333

# %%
# Plot
fig, axes = plt.subplots(1, 4, figsize=(10,3), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:4]):
    lag_plot(ss.value, lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))

fig.suptitle('Lag Plots of Sun Spots Area \n(Points get wide and scattered with increasing lag -> lesser correlation)\n', y=1.15)    
plt.show()

# %%
a10.head()
# Out:
#          date     value
# 0  1991-07-01  3.526591
# 1  1991-08-01  3.180891
# 2  1991-09-01  3.252221
# 3  1991-10-01  3.611003
# 4  1991-11-01  3.565869

# %%
fig, axes = plt.subplots(1, 4, figsize=(10,3), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:4]):
    lag_plot(a10.value, lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))

fig.suptitle('Lag Plots of Drug Sales', y=1.05)    
plt.show()

# %%
fig, axes = plt.subplots(3, 4, figsize=(10,9), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()):
    lag_plot(a10.value, lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1), fontsize=9)
    # print('i: {}, ax: {}'.format(i, ax))

fig.suptitle('Lag Plots of Drug Sales')    
fig.tight_layout()
plt.show()
